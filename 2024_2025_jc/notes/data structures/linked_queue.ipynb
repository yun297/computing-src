# %% [markdown]
# ### Node Class

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %% [markdown]
# ### Queue Class

# %%
class Queue:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def enqueue(self, data):
        new_node = Node(data)
        
        if not self.head:
            self.head == new_node
            self.tail == new_node
        
        else:
            self.tail.next = new_node
            self.tail = new_node
        
    def dequeue(self):
        if self.head:
            removed = self.head.data
            
            self.head = self.head.next
        
            # if there was only one node left, self.tail is still pointing to it
            if not self.head:
                self.tail = None
            
            return removed
        
        else:
            print("Queue is empty")
            return None
