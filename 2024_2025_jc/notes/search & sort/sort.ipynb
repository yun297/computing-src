# %% [markdown]
# ### Bubble Sort

# %%
from random import choices

rand_list = choices(range(100), k = 20)

print(rand_list)
# Out:
# [44, 69, 66, 95, 96, 43, 89, 92, 54, 29, 23, 75, 30, 3, 80, 1, 20, 27, 9, 63]

# %%
def bubble1(arr: list):
    new_arr = arr.copy()
    
    for i in range(len(new_arr) - 1):
        for j in range(len(new_arr) - 1):
            if new_arr[j] > new_arr[j + 1]:
                new_arr[j], new_arr[j + 1] = new_arr[j + 1], new_arr[j]
    
    return new_arr

print(bubble1(rand_list))
# Out:
# [5, 11, 13, 13, 24, 25, 25, 38, 40, 40, 44, 47, 49, 52, 54, 57, 81, 83, 89, 94]

# %%
def bubble2(arr: list):
    new_arr = arr.copy()
    
    for i in range(len(new_arr) - 1):
        for j in range(len(new_arr) - 1 - i):
            if new_arr[j] > new_arr[j + 1]:
                new_arr[j], new_arr[j + 1] = new_arr[j + 1], new_arr[j]
    
    return new_arr

print(bubble2(rand_list))
# Out:
# [5, 11, 13, 13, 24, 25, 25, 38, 40, 40, 44, 47, 49, 52, 54, 57, 81, 83, 89, 94]

# %%
def bubble3(arr):
    n = len(arr)
    
    while n > 1:
        last_swap = 1
        for i in range(1, n):
            if arr[i] < arr[i - 1]:
                arr[i], arr[i - 1] = arr[i - 1], arr[i]
                last_swap = i   # remember last swap position
                
        n = last_swap
        
    return arr

print(bubble3(rand_list))
# Out:
# [5, 11, 13, 13, 24, 25, 25, 38, 40, 40, 44, 47, 49, 52, 54, 57, 81, 83, 89, 94]

# %% [markdown]
# ### Insertion Sort

# %%
from random import choices

rand_list = choices(range(100), k = 20)

print(rand_list)
# Out:
# [45, 56, 80, 97, 0, 99, 86, 18, 7, 16, 56, 26, 1, 62, 30, 22, 52, 13, 27, 78]

# %%
def insertion(arr: list): 
    new_arr = arr.copy()
    
    for i in range(1, len(new_arr)):
        space = i
        compare = new_arr[space]
        
        while space > 0 and new_arr[space - 1] > compare:
            new_arr[space] = new_arr[space - 1]
            space -= 1

        new_arr[space] = compare

    return new_arr

print(insertion(rand_list))
# Out:
# [0, 1, 7, 13, 16, 18, 22, 26, 27, 30, 45, 52, 56, 56, 62, 78, 80, 86, 97, 99]

# %% [markdown]
# ### Quick Sort

# %%
from random import choices

rand_list = choices(range(100), k = 20)

print(rand_list)
# Out:
# [58, 89, 27, 40, 23, 7, 22, 18, 20, 63, 38, 77, 7, 49, 58, 88, 17, 62, 41, 34]

# %%
def quick(arr: list): # not in-place version
    if len(arr) <= 1:
        return arr

    pivot = arr[0]
    left = []
    right = []

    for item in arr[1:]:
        if item > pivot:
            right.append(item)
        else:
            left.append(item)

    return quick(left) + [pivot] + quick(right)

print(quick(rand_list))
# Out:
# [7, 7, 17, 18, 20, 22, 23, 27, 34, 38, 40, 41, 49, 58, 58, 62, 63, 77, 88, 89]

# %%
def quick2(arr: list):  # "functional" style, but updates in place
    if len(arr) <= 1:
        return arr

    pivot = arr[0]
    left = []
    right = []

    for item in arr[1:]:
        if item > pivot:
            right.append(item)
        else:
            left.append(item)

    # get sorted result
    sorted_arr = quick2(left) + [pivot] + quick2(right)

    # overwrite arr with sorted_arr (important part)
    arr[:] = sorted_arr
    return arr

print(rand_list)
quick2(rand_list)
print(rand_list)
# Out:
# [58, 89, 27, 40, 23, 7, 22, 18, 20, 63, 38, 77, 7, 49, 58, 88, 17, 62, 41, 34]
# [7, 7, 17, 18, 20, 22, 23, 27, 34, 38, 40, 41, 49, 58, 58, 62, 63, 77, 88, 89]

# %%
def quick3(arr): # in-place
    def quick_helper(arr, left, right):
        if left < right: # at least 2 elements
            pivot = arr[left]
            space = left
            
            for i in range(left + 1, right + 1): # from left + 1 (to skip pivot) until right
                if arr[i] < pivot:
                    space += 1
                    arr[i], arr[space] = arr[space], arr[i]
            
            arr[left], arr[space] = arr[space], arr[left]

            quick_helper(arr, left, space - 1)
            quick_helper(arr, space + 1, right)
        
    quick_helper(arr, 0, len(arr) - 1)
    
print(rand_list)
quick3(rand_list)
print(rand_list)
# Out:
# [7, 7, 17, 18, 20, 22, 23, 27, 34, 38, 40, 41, 49, 58, 58, 62, 63, 77, 88, 89]
# [7, 7, 17, 18, 20, 22, 23, 27, 34, 38, 40, 41, 49, 58, 58, 62, 63, 77, 88, 89]

# %%
from random import choices

rand_list = choices(range(100), k = 20)

print(rand_list)
# Out:
# [0, 58, 25, 38, 8, 31, 34, 30, 1, 30, 79, 99, 83, 49, 82, 28, 58, 95, 42, 75]

# %% [markdown]
# ### Merge Sort

# %%
from random import choices

rand_list = choices(range(100), k = 20)

print(rand_list)
# Out:
# [97, 82, 37, 13, 54, 82, 22, 70, 17, 71, 65, 26, 99, 20, 45, 8, 25, 37, 8, 75]

# %%
def merge1(arr: list): # in place version
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    
    left = merge1(arr[:mid])
    right = merge1(arr[mid:])
    
    l = r = i = 0
    
    while l < len(left) and r < len(right):
        if left[l] < right[r]:
            arr[i] = left[l]
            l += 1
        else:
            arr[i] = right[r]
            r += 1
        i += 1
    
    while l < len(left):
        arr[i] = left[l]
        i += 1
        l += 1
        
    while r < len(right):
        arr[i] = right[r]
        i += 1
        r += 1
    
    return arr

print(merge1(rand_list))
# Out:
# [8, 8, 16, 17, 22, 35, 37, 38, 47, 48, 52, 52, 53, 56, 72, 74, 76, 79, 83, 83]

# %%
def merge2(arr: list): # not in place version
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    
    left = merge2(arr[:mid])
    right = merge2(arr[mid:])

    result = []
    l = r = 0

    while l < len(left) and r < len(right):
        if left[l] < right[r]:
            result.append(left[l])
            l += 1
        else:
            result.append(right[r])
            r += 1

    while l < len(left):
        result.append(left[l])
        l += 1

    while r < len(right):
        result.append(right[r])
        r += 1

    return result

print(rand_list)

print(merge2(rand_list))
# Out:
# [97, 82, 37, 13, 54, 82, 22, 70, 17, 71, 65, 26, 99, 20, 45, 8, 25, 37, 8, 75]
# [8, 8, 13, 17, 20, 22, 25, 26, 37, 37, 45, 54, 65, 70, 71, 75, 82, 82, 97, 99]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
