# %%
# Task 2.1

from random import randint

def task2_1(filename, quantity, maximum):
    int_list = []
    
    for i in range(quantity):
        int_list.append(str(randint(0, maximum)))

    f = open(filename, 'w')
    f.write("\n".join(int_list))
    f.close()

task2_1("randomnumbers_Zhu_Yunsong", 1000, 5000)

# %%
# Task 2.2

def task2_2(list_of_integers):
    if len(list_of_integers) <= 1:
        return list_of_integers

    mid = len(list_of_integers) // 2

    left = task2_2(list_of_integers[:mid])
    right = task2_2(list_of_integers[mid:])

    l = r = 0
    result = []

    while l < len(left) and r < len(right):
        if left[l] < right[r]:
            result.append(left[l])
            l += 1
        else:
            result.append(right[r])
            r += 1

    while l < len(left):
        result.append(left[l])
        l += 1

    while r < len(right):
        result.append(right[r])
        r += 1

    return result

task2_2([56,25,4,98,0,18,4,5,7,0]) == [0,0,4,4,5,7,18,25,56,98]
# Out:
# True

# %%
# Task 2.3

def task2_3(filename_in, filename_out):
