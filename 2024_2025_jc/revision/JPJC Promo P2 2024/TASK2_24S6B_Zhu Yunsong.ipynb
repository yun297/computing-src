# %%
# Task 2.1

def binary_to_denary(binary_str):
    for char in binary_str:
        if char != '0' and char != '1':
            print("String is not a valid binary string!")
            return

    den = 0

    for i in range(len(binary_str)):
        den += int(binary_str[len(binary_str) - 1 - i]) * 2**i

    return den

print(binary_to_denary("1100100"))
binary_to_denary("11001AB")
# Out:
# 100
# String is not a valid binary string!

# %%
# Task 2.2

def convert_to_base(denary_int, base):
    if denary_int == 0:
        return '0'

    digits = "0123456789ABCDEF"
    result = ""
    quotient = denary_int

    while quotient > 0:
        remainder = quotient % base
        quotient = quotient // base
        result = digits[remainder] + result

    return result

print(convert_to_base(100, 2))
print(convert_to_base(168, 16))
# Out:
# 1100100
# A8
